# %%
import sys
import os
import pandas as pd
import json
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
import re
import string

# %%
WORK_DIR = "/home/nguyen/"
RAW_DATA = "/data/labeled_tweets.txt"
PROCESSED_DATA = "data/processed_tweets.csv"

# %%
stop_words = set(stopwords.words('english'))

# %%
# pre-process tweet
def preprocess(text, isStopWords = False):
    tokenizer = TweetTokenizer()
    tokens = tokenizer.tokenize(text)

    # convert to lower case
    tokens = [token.lower() for token in tokens]
    # print("Lower case: {}\n".format(tokens))

    # remove html tags
    html_regex = re.compile("<[^>]+>")
    tokens = [token for token in tokens if not html_regex.match(token)]
    # print("removed HTML: {}\n".format(tokens))

    # replace all mentions by @user
    mention_regex = re.compile("(rt @[\w_]+)")
    tokens = ['' if mention_regex.match(token) else token for token in tokens]
    # print("removed Mentions: {}\n".format(tokens))

    # replace all urls by !url
    url_regex = re.compile('http[s]?://(?:[a-z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+')
    tokens = ['' if url_regex.match(token) else token for token in tokens]
    # print("removed URL: {}\n".format(tokens))

    # remove punctuations
    # punctuation = "\"@!$%&'()*+,-./:;<=>?[\]^_`{|}~"
    table = str.maketrans('', '', string.punctuation)
    tokens = [token.translate(table) for token in tokens]
    # print("removed Punctuations: {}\n".format(tokens))

    # remove all tokens that are not alphabetic
    tokens = [token for token in tokens if token.isalpha()]
    # print("removed Non-alphabets: {}\n".format(tokens))

    # remove stop words
    if isStopWords == False:
        tokens = [token for token in tokens if not token in stop_words]
    # print("removed Stopwords: {}\n".format(tokens))

    tweet = ' '.join(token for token in tokens if len(token)!=0)
    return tweet

# %%
# Read raw dataset, process and print to file
def read_and_print_data():
    file = open(WORK_DIR+RAW_DATA, "r")
    lines = file.readlines()
    data = []
    i=0
    for line in lines:
        tweet = line.split("\t")
        label = tweet[0]
        text = json.loads(tweet[1])
        text = str(text['full_text'])
        text = preprocess(text)
        data.append([text, label])
        i+=1
        if i %1000 ==0:
            print("Line {}: {}, label: {}\n".format(i, text, label))
#             break
    output = pd.DataFrame(data, columns=['tweets', 'labels'])
    
    output.to_csv(WORK_DIR+PROCESSED_DATA, index=False)
    file.close()

# %%
read_and_print_data()
# Out:
# Line 1000: michael bloomberg says election better forum remove trump office formal impeachment inquiry, label: Politics
#
# Line 2000: texas congressman pulls endorsement julián castro support joe biden, label: Politics
#
# Line 3000: cherokee nation names first ever delegate congress, label: Politics
#
# Line 4000: u officials huddle facebook google tech giants talk election, label: Politics
#
# Line 5000: trump cutting medicare give tax breaks billionaires, label: Politics
#
# Line 6000: trump consistent criticism iran pushes u point potential conflict, label: Politics
#
# Line 7000: trump hits back ally denounces weakness iran, label: Politics
#
# Line 8000: news analysis violence escalates across asia washington chosen inaction governments ignoring trump administration calls calm, label: Politics
#
# Line 9000: power went de blasio, label: Politics
#
# Line 10000: pete buttigieg criticized responses elizabeth warren provided asked whether medicare plan raise middleclass taxes, label: Politics
#
# Line 11000: president trump campaign named clear winner first night democratic debate cnn prepare amazed, label: Politics
#
# Line 12000: ayatollah ruhollah khomeini irans supreme leader died succeeded current supreme leader ali khamenei, label: Politics
#
# Line 13000: rt devindwyer breaking supreme court takes louisiana abortion restrictions case first test abortion courts new cons, label: Politics
#
# Line 14000: federal reserve says keep pumping cash vital obscure corner u financial markets coming weeks, label: Politics
#
# Line 15000: president trump anniversary seek conflict anyone dares strike land respond full measure american power iron american spirit neverforget, label: Politics
#
# Line 16000: note even dont add serious threat presidents renomination primary challenges history weakening incumbents exposing vulnerabilities abc news rickklein writes, label: Politics
#
# Line 17000: hillary clinton return ohio amid optimism early voting via hannahfc, label: Politics
#
# Line 18000: heres gop inprimary voters angry government voted, label: Politics
#
# Line 19000: super tuesday gop ready donald trump takeover via stephcondoncbs, label: Politics
#
# Line 20000: democrats speak impeachment house inquiry ramps, label: Politics
#
# Line 21000: watch candidates faced detroit night second democratic debate, label: Politics
#
# Line 22000: first lady says twitter stephanie grisham director communications next white house director communications well press secretary excited stephanie working sides white house, label: Politics
#
# Line 23000: state department inspector general plans brief several house committees wednesday documents related ukraine according house official familiar matter, label: Politics
#
# Line 24000: never posttrump republican party, label: Politics
#
# Line 25000: rt nextchina hong kong media tycoon democracy advocate jimmy lai says doesnt care labeled traitor beijing htt, label: Politics
#
# Line 26000: second time two days president united states falsely accused democratic congressman treason, label: Politics
#
# Line 27000: rep seth moulton dmass exit presidential race announce run reelection congress, label: Politics
#
# Line 28000: georgia state rep erica thomas described victim racist verbal attack supermarket, label: Politics
#
# Line 29000: president trump said tweet ice would begin removing millions illegal aliens next week, label: Politics
#
# Line 30000: rt time president trump accuses new york times virtual act treason article administration reportedly clear, label: Politics
#
# Line 31000: republican senators defend john mccains legacy president trump goes attack, label: Politics
#
# Line 32000: see special counsel robert mueller named runner times person year timepoy via bybrianbennett tcberenson, label: Politics
#
# Line 33000: boris johnson parliament shutdown defeated means happens next, label: Politics
#
# Line 34000: deal brexit spending tops boris johnson confirms huge new fund, label: Politics
#
# Line 35000: trump comment gave green light russia interfere us election, label: Politics
#
# Line 36000: home office suspected prioritising help highprofile eu citizens, label: Politics
#
# Line 37000: irony humour tory leadership debate letters, label: Politics
#
# Line 38000: brexiter mps call confidence vote may block delay, label: Politics
